# %% [markdown]
# # ST / scRNA gene imputation
#
# This notebook is the main entry point. It imports the reusable modules under `src/vae_imputer/` and runs the pipeline end to end.

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))

from vae_imputer.pipeline import run_pipeline

# %%
# ===== Configuration =====
# Adjust these paths to match your local dataset layout.
BASE_PATH = "/work/data1/GUOMENGKE/CuiYaxuan/SpatialAD/Orgdata/H21.33.015"
SP_REL_PATH = "spatial/H21.33.015_Section_H21.33.015.Cx26.MTG.02.007.1.0.h5ad"
SC_REL_PATH = "scRNA/H21.33.015_scRNA.h5ad"
OUTPUT_FILE = "H21.33.015_Section_ST_layer56_separation_imputed.h5ad"

# Optional marker genes used by the notebook. Keep empty if you do not have a curated marker list.
LAYER_MARKER_GENES = []

# %%
# ===== Run =====
adata_out = run_pipeline(
    base_path=BASE_PATH,
    sp_rel_path=SP_REL_PATH,
    sc_rel_path=SC_REL_PATH,
    output_file=OUTPUT_FILE,
    layer_marker_genes=LAYER_MARKER_GENES,
    seed=0,
)

adata_out
# Out:
# /home/guomengke/anaconda3/envs/pipeline/lib/python3.8/site-packages/scanpy/preprocessing/_highly_variable_genes.py:64: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(
# [sc pretrain] Epoch 00 | train=0.2007 | val=0.1018
# [sc pretrain] Epoch 05 | train=0.0736 | val=0.0658
# [sc pretrain] Epoch 10 | train=0.0660 | val=0.0580
# [sc pretrain] Epoch 15 | train=0.0614 | val=0.0531
# [sc pretrain] Epoch 20 | train=0.0584 | val=0.0500
# [sc pretrain] Epoch 25 | train=0.0560 | val=0.0481
# [sc pretrain] Epoch 30 | train=0.0541 | val=0.0461
# [sc pretrain] Epoch 35 | train=0.0527 | val=0.0445
# [sc pretrain] Epoch 39 | train=0.0517 | val=0.0433
# [ST finetune] Epoch 00 | loss=0.9626
# [ST finetune] Epoch 02 | loss=0.9490
# [ST finetune] Epoch 04 | loss=0.9395
# [ST finetune] Epoch 06 | loss=0.9309
# [ST finetune] Epoch 08 | loss=0.9226
# [ST finetune] Epoch 10 | loss=0.9149
# [ST finetune] Epoch 12 | loss=0.9070
# ...

# %%
# ===== Inspect result =====
print(adata_out)
print("Output file:", OUTPUT_FILE)
print("Genes:", adata_out.n_vars)
print("Cells/spots:", adata_out.n_obs)
# Out:
# AnnData object with n_obs × n_vars = 27229 × 5056
# ...
